# %%
import pandas as pd
df = pd.read_csv('data/french-ambs.csv')
df.shape
# Out:
# (869, 7)

# %%
df
# Out:
#       id                                  name              place  year  \
# 0      0                    Richer, Christophe            Denmark  1543
# 1      1                    Richer, Christophe            Denmark  1541
# 2      2                    Danzay, Charles de            Denmark  1561
# 3      3                    Danzay, Charles de            Denmark  1563
# 4      4                    Danzay, Charles de            Denmark  1582
# ..   ...                                   ...                ...   ...
# 864  864                     Canossa, Louis de             Venice  1526
# 865  865                       Vigier, Jacques      Swiss Cantons  1597
# 866  866                     De Selve, Georges             Venice  1537
# 867  867  Noailles, François de, Bishop of Dax             Venice  1559
# 868  868                    Calvimont, Jean de  Holy Roman Empire  1525
#
#        lat   long      lat_long
# 0    55.68  12.57  55.68, 12.57
# 1    55.68  12.57  55.68, 12.57
# ...

# %%
df_filter = df[(df['year'] < 1592) & (df['year'] > 1588)]
df_filter.shape
# Out:
# (21, 7)

# %%
df["is_permanent"] = True
df
# Out:
#       id                                  name              place  year  \
# 0      0                    Richer, Christophe            Denmark  1543
# 1      1                    Richer, Christophe            Denmark  1541
# 2      2                    Danzay, Charles de            Denmark  1561
# 3      3                    Danzay, Charles de            Denmark  1563
# 4      4                    Danzay, Charles de            Denmark  1582
# ..   ...                                   ...                ...   ...
# 864  864                     Canossa, Louis de             Venice  1526
# 865  865                       Vigier, Jacques      Swiss Cantons  1597
# 866  866                     De Selve, Georges             Venice  1537
# 867  867  Noailles, François de, Bishop of Dax             Venice  1559
# 868  868                    Calvimont, Jean de  Holy Roman Empire  1525
#
#        lat   long      lat_long  is_permanent
# 0    55.68  12.57  55.68, 12.57          True
# ...

# %%
df["is_permanent"][(df["place"] == "Geneva") | (df["place"] == "Saxony") | (df["place"] == "Tuscany") | (df["place"] == "Ferrara")] = False
# Out:
# /var/folders/cc/k2w3n13x3sndt6mbgq0813c40000gp/T/ipykernel_88368/495637465.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
df[df["is_permanent"] == False].shape
# Out:
# (11, 8)

# %%
df["place"][(df["place"] == "Geneva") | (df["place"] == "Grisons")] = "Swiss Cantons"
# Out:
# /var/folders/cc/k2w3n13x3sndt6mbgq0813c40000gp/T/ipykernel_88368/614014330.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["place"][(df["place"] == "Geneva") | (df["place"] == "Grisons")] = "Swiss Cantons"
# ...

# %%
df
# Out:
#       id                                  name              place  year  \
# 0      0                    Richer, Christophe            Denmark  1543
# 1      1                    Richer, Christophe            Denmark  1541
# 2      2                    Danzay, Charles de            Denmark  1561
# 3      3                    Danzay, Charles de            Denmark  1563
# 4      4                    Danzay, Charles de            Denmark  1582
# ..   ...                                   ...                ...   ...
# 864  864                     Canossa, Louis de             Venice  1526
# 865  865                       Vigier, Jacques      Swiss Cantons  1597
# 866  866                     De Selve, Georges             Venice  1537
# 867  867  Noailles, François de, Bishop of Dax             Venice  1559
# 868  868                    Calvimont, Jean de  Holy Roman Empire  1525
#
#        lat   long      lat_long  is_permanent
# 0    55.68  12.57  55.68, 12.57          True
# ...

# %%
df[df["place"] == "Swiss Cantons"].shape
# Out:
# (210, 8)

# %%
df_agg = df.groupby(["place"]).agg({"year": "nunique", "name": "nunique"})
df_agg
# Out:
#                    year  name
# place
# Denmark              40     2
# England              74    26
# Ferrara               3     2
# Holy Roman Empire    70    15
# Netherlands          43    12
# Ottoman Empire       66    20
# Poland                3     5
# Portugal             55     5
# Rome                 59    24
# Savoy                 3     3
# Saxony                3     1
# Scotland             21     4
# Spain                31     5
# Swiss Cantons        79    39
# Tuscany               3     1
# Venice               80    20

# %%
df_agg = df_agg.rename(columns={"year": "years_present", "name": "unique_ambs"})
df_agg.sort_values(by="unique_ambs", ascending=True)
# Out:
#                    years_present  unique_ambs
# place
# Saxony                         3            1
# Tuscany                        3            1
# Denmark                       40            2
# Ferrara                        3            2
# Savoy                          3            3
# Scotland                      21            4
# Poland                         3            5
# Portugal                      55            5
# Spain                         31            5
# Netherlands                   43           12
# Holy Roman Empire             70           15
# Ottoman Empire                66           20
# Venice                        80           20
# Rome                          59           24
# England                       74           26
# Swiss Cantons                 79           39

# %%
df_agg.sort_values(by='unique_ambs')
# Out:
#                    years_present  unique_ambs
# place
# Saxony                         3            1
# Tuscany                        3            1
# Denmark                       40            2
# Ferrara                        3            2
# Savoy                          3            3
# Scotland                      21            4
# Poland                         3            5
# Portugal                      55            5
# Spain                         31            5
# Netherlands                   43           12
# Holy Roman Empire             70           15
# Ottoman Empire                66           20
# Venice                        80           20
# Rome                          59           24
# England                       74           26
# Swiss Cantons                 79           39
